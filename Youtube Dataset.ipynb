# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv('../DataSets/youtube_channels_1M_clean.csv')
df
# Out:
#                        channel_id              channel_link  \
# 0        UCUMHFa347GD8EIRaVVuxR8Q             /@TonettaClay
# 1        UC28mqg7IlYWEhrZwHb72IQA     /@FoodnHappinessVeena
# 2        UCoLwWY9zQ7Jp8aDtYUszmYg               /@TimShieff
# 3        UCAQOeJwsgBMC74-OjjcQcJA      /@JerryAndJulieMusic
# 4        UCOqwGhI1AmpWwxMYw9D_fqw  /@KichuandYugiMagizhakam
# ...                           ...                       ...
# 1095237  UCv5MGa5MlPJs-Hnb83MM86Q         /@PAULETTELANVLOG
# 1095238  UCv9ddmW76c7aVVx4QscPn-A        /@ellyphysique4068
# 1095239  UC23Wx4sNPxvfjCSlaJrus1A           /@UmaPaul-fb4he
# 1095240  UCB4ztUZpdzX30Y5vdr7J6eg          /@CrispyGreenInc
# 1095241  UCB018l_D1v-i2kNJXATTusg          /@uniquecraftsnl
#
#                       channel_name  subscriber_count  \
# 0                     Tonetta Clay               781
# 1               Food 'n' Happiness                 0
# 2                       Tim Shieff            166000
# ...

# %%
print("NaN values before removal:")
# Out:
# NaN values before removal:

# %%
print(df.isna().sum())
# Out:
# channel_id                          0
# channel_link                        0
# channel_name                       60
# subscriber_count                    0
# banner_link                    328365
# description                    275499
# keywords                       548038
# avatar                              0
# country                        475183
# total_views                       752
# total_videos                      257
# join_date                          22
# mean_views_last_30_videos       36157
# median_views_last_30_videos     36157
# std_views_last_30_videos        36157
# videos_per_week                 36157
# dtype: int64

# %%
columns_to_clean = ['country','keywords','description','banner_link','total_videos','mean_views_last_30_videos','median_views_last_30_videos','std_views_last_30_videos','videos_per_week']

# %%
df.dropna(subset=columns_to_clean, inplace=True)

# %%
df
# Out:
#                        channel_id             channel_link  \
# 2        UCoLwWY9zQ7Jp8aDtYUszmYg              /@TimShieff
# 3        UCAQOeJwsgBMC74-OjjcQcJA     /@JerryAndJulieMusic
# 5        UCkcc9W34khoJeQA6Eypp0JA        /@burhanzohan2341
# 9        UCWTnzxJ58oAfydJ_0Fgm6fg  /@yourshealthbeauty7219
# 10       UCDQQbOfutK7zv3O0XbMD8-w      /@AsiaHealthChannel
# ...                           ...                      ...
# 1095225  UC96ABhfio4usZ48ea6yPrTg           /@goru_mudhalu
# 1095233  UCfBCbJEpUJo6tBoQtzdvbwA              /@Zak4KTour
# 1095234  UC4m2WvOQ2odYsrcD2dbAIbA            /@YogiFitness
# 1095236  UC9Ej16ho_F8DpkYGvi1tPKQ              /@ayueidris
# 1095237  UCv5MGa5MlPJs-Hnb83MM86Q        /@PAULETTELANVLOG
#
#                   channel_name  subscriber_count  \
# 2                   Tim Shieff            166000
# 3          Jerry & Julie Music              1090
# 5               Burhan & Zohan               617
# 9        Yours Health & Beauty              1380
# ...

# %%
print(df.isna().sum())
# Out:
# channel_id                      0
# channel_link                    0
# channel_name                   26
# subscriber_count                0
# banner_link                     0
# description                     0
# keywords                        0
# avatar                          0
# country                         0
# total_views                    55
# total_videos                    0
# join_date                       1
# mean_views_last_30_videos       0
# median_views_last_30_videos     0
# std_views_last_30_videos        0
# videos_per_week                 0
# dtype: int64

# %%
columns_to_clean =['channel_name','total_views','join_date']

# %%
a=df.dropna(subset=columns_to_clean, inplace=True)
a

# %%
print(df.isna().sum())
# Out:
# channel_id                     0
# channel_link                   0
# channel_name                   0
# subscriber_count               0
# banner_link                    0
# description                    0
# keywords                       0
# avatar                         0
# country                        0
# total_views                    0
# total_videos                   0
# join_date                      0
# mean_views_last_30_videos      0
# median_views_last_30_videos    0
# std_views_last_30_videos       0
# videos_per_week                0
# dtype: int64

# %%
df
# Out:
#                        channel_id             channel_link  \
# 2        UCoLwWY9zQ7Jp8aDtYUszmYg              /@TimShieff
# 3        UCAQOeJwsgBMC74-OjjcQcJA     /@JerryAndJulieMusic
# 5        UCkcc9W34khoJeQA6Eypp0JA        /@burhanzohan2341
# 9        UCWTnzxJ58oAfydJ_0Fgm6fg  /@yourshealthbeauty7219
# 10       UCDQQbOfutK7zv3O0XbMD8-w      /@AsiaHealthChannel
# ...                           ...                      ...
# 1095225  UC96ABhfio4usZ48ea6yPrTg           /@goru_mudhalu
# 1095233  UCfBCbJEpUJo6tBoQtzdvbwA              /@Zak4KTour
# 1095234  UC4m2WvOQ2odYsrcD2dbAIbA            /@YogiFitness
# 1095236  UC9Ej16ho_F8DpkYGvi1tPKQ              /@ayueidris
# 1095237  UCv5MGa5MlPJs-Hnb83MM86Q        /@PAULETTELANVLOG
#
#                   channel_name  subscriber_count  \
# 2                   Tim Shieff            166000
# 3          Jerry & Julie Music              1090
# 5               Burhan & Zohan               617
# 9        Yours Health & Beauty              1380
# ...

# %%
column_name = 'channel_link'

# %%
df[column_name] = df[column_name].str.replace('/@', '')
df
# Out:
#                        channel_id           channel_link  \
# 2        UCoLwWY9zQ7Jp8aDtYUszmYg              TimShieff
# 3        UCAQOeJwsgBMC74-OjjcQcJA     JerryAndJulieMusic
# 5        UCkcc9W34khoJeQA6Eypp0JA        burhanzohan2341
# 9        UCWTnzxJ58oAfydJ_0Fgm6fg  yourshealthbeauty7219
# 10       UCDQQbOfutK7zv3O0XbMD8-w      AsiaHealthChannel
# ...                           ...                    ...
# 1095225  UC96ABhfio4usZ48ea6yPrTg           goru_mudhalu
# 1095233  UCfBCbJEpUJo6tBoQtzdvbwA              Zak4KTour
# 1095234  UC4m2WvOQ2odYsrcD2dbAIbA            YogiFitness
# 1095236  UC9Ej16ho_F8DpkYGvi1tPKQ              ayueidris
# 1095237  UCv5MGa5MlPJs-Hnb83MM86Q        PAULETTELANVLOG
#
#                   channel_name  subscriber_count  \
# 2                   Tim Shieff            166000
# 3          Jerry & Julie Music              1090
# 5               Burhan & Zohan               617
# 9        Yours Health & Beauty              1380
# ...

# %%
column_to_remove = 'avatar'
column_to_remove ='channel_link'
column_to_remove='banner_link'
column_to_remove='description'

# %%
df = df.drop(column_to_remove, axis=1)
df
# Out:
#                        channel_id           channel_link  \
# 2        UCoLwWY9zQ7Jp8aDtYUszmYg              TimShieff
# 3        UCAQOeJwsgBMC74-OjjcQcJA     JerryAndJulieMusic
# 5        UCkcc9W34khoJeQA6Eypp0JA        burhanzohan2341
# 9        UCWTnzxJ58oAfydJ_0Fgm6fg  yourshealthbeauty7219
# 10       UCDQQbOfutK7zv3O0XbMD8-w      AsiaHealthChannel
# ...                           ...                    ...
# 1095225  UC96ABhfio4usZ48ea6yPrTg           goru_mudhalu
# 1095233  UCfBCbJEpUJo6tBoQtzdvbwA              Zak4KTour
# 1095234  UC4m2WvOQ2odYsrcD2dbAIbA            YogiFitness
# 1095236  UC9Ej16ho_F8DpkYGvi1tPKQ              ayueidris
# 1095237  UCv5MGa5MlPJs-Hnb83MM86Q        PAULETTELANVLOG
#
#                   channel_name  subscriber_count  \
# 2                   Tim Shieff            166000
# 3          Jerry & Julie Music              1090
# 5               Burhan & Zohan               617
# 9        Yours Health & Beauty              1380
# ...

# %%
a=df

# %%
a
# Out:
#                        channel_id           channel_link  \
# 2        UCoLwWY9zQ7Jp8aDtYUszmYg              TimShieff
# 3        UCAQOeJwsgBMC74-OjjcQcJA     JerryAndJulieMusic
# 5        UCkcc9W34khoJeQA6Eypp0JA        burhanzohan2341
# 9        UCWTnzxJ58oAfydJ_0Fgm6fg  yourshealthbeauty7219
# 10       UCDQQbOfutK7zv3O0XbMD8-w      AsiaHealthChannel
# ...                           ...                    ...
# 1095225  UC96ABhfio4usZ48ea6yPrTg           goru_mudhalu
# 1095233  UCfBCbJEpUJo6tBoQtzdvbwA              Zak4KTour
# 1095234  UC4m2WvOQ2odYsrcD2dbAIbA            YogiFitness
# 1095236  UC9Ej16ho_F8DpkYGvi1tPKQ              ayueidris
# 1095237  UCv5MGa5MlPJs-Hnb83MM86Q        PAULETTELANVLOG
#
#                   channel_name  subscriber_count  \
# 2                   Tim Shieff            166000
# 3          Jerry & Julie Music              1090
# 5               Burhan & Zohan               617
# 9        Yours Health & Beauty              1380
# ...

# %%
column_to_remove = 'banner_link'
column_to_remove = 'avatar'

# %%
df = df.drop(column_to_remove, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 df = df.drop(column_to_remove, axis=1)
#
# File E:\Musics\Anaconda\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File E:\Musics\Anaconda\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
df
# Out:
#                        channel_id           channel_link  \
# 2        UCoLwWY9zQ7Jp8aDtYUszmYg              TimShieff
# 3        UCAQOeJwsgBMC74-OjjcQcJA     JerryAndJulieMusic
# 5        UCkcc9W34khoJeQA6Eypp0JA        burhanzohan2341
# 9        UCWTnzxJ58oAfydJ_0Fgm6fg  yourshealthbeauty7219
# 10       UCDQQbOfutK7zv3O0XbMD8-w      AsiaHealthChannel
# ...                           ...                    ...
# 1095225  UC96ABhfio4usZ48ea6yPrTg           goru_mudhalu
# 1095233  UCfBCbJEpUJo6tBoQtzdvbwA              Zak4KTour
# 1095234  UC4m2WvOQ2odYsrcD2dbAIbA            YogiFitness
# 1095236  UC9Ej16ho_F8DpkYGvi1tPKQ              ayueidris
# 1095237  UCv5MGa5MlPJs-Hnb83MM86Q        PAULETTELANVLOG
#
#                   channel_name  subscriber_count  \
# 2                   Tim Shieff            166000
# 3          Jerry & Julie Music              1090
# 5               Burhan & Zohan               617
# 9        Yours Health & Beauty              1380
# ...

# %%
cleaned_Data = df

# %%
cleaned_Data
# Out:
#                        channel_id           channel_link  \
# 2        UCoLwWY9zQ7Jp8aDtYUszmYg              TimShieff
# 3        UCAQOeJwsgBMC74-OjjcQcJA     JerryAndJulieMusic
# 5        UCkcc9W34khoJeQA6Eypp0JA        burhanzohan2341
# 9        UCWTnzxJ58oAfydJ_0Fgm6fg  yourshealthbeauty7219
# 10       UCDQQbOfutK7zv3O0XbMD8-w      AsiaHealthChannel
# ...                           ...                    ...
# 1095225  UC96ABhfio4usZ48ea6yPrTg           goru_mudhalu
# 1095233  UCfBCbJEpUJo6tBoQtzdvbwA              Zak4KTour
# 1095234  UC4m2WvOQ2odYsrcD2dbAIbA            YogiFitness
# 1095236  UC9Ej16ho_F8DpkYGvi1tPKQ              ayueidris
# 1095237  UCv5MGa5MlPJs-Hnb83MM86Q        PAULETTELANVLOG
#
#                   channel_name  subscriber_count  \
# 2                   Tim Shieff            166000
# 3          Jerry & Julie Music              1090
# 5               Burhan & Zohan               617
# 9        Yours Health & Beauty              1380
# ...

# %%
df
# Out:
#                        channel_id           channel_link  \
# 2        UCoLwWY9zQ7Jp8aDtYUszmYg              TimShieff
# 3        UCAQOeJwsgBMC74-OjjcQcJA     JerryAndJulieMusic
# 5        UCkcc9W34khoJeQA6Eypp0JA        burhanzohan2341
# 9        UCWTnzxJ58oAfydJ_0Fgm6fg  yourshealthbeauty7219
# 10       UCDQQbOfutK7zv3O0XbMD8-w      AsiaHealthChannel
# ...                           ...                    ...
# 1095225  UC96ABhfio4usZ48ea6yPrTg           goru_mudhalu
# 1095233  UCfBCbJEpUJo6tBoQtzdvbwA              Zak4KTour
# 1095234  UC4m2WvOQ2odYsrcD2dbAIbA            YogiFitness
# 1095236  UC9Ej16ho_F8DpkYGvi1tPKQ              ayueidris
# 1095237  UCv5MGa5MlPJs-Hnb83MM86Q        PAULETTELANVLOG
#
#                   channel_name  subscriber_count  \
# 2                   Tim Shieff            166000
# 3          Jerry & Julie Music              1090
# 5               Burhan & Zohan               617
# 9        Yours Health & Beauty              1380
# ...
